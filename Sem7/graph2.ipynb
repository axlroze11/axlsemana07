# %%
import networkx nx
# Out:
#   File "<ipython-input-1-fedb187bcc0a>", line 1
#     import networkx nx
#                      ^
# SyntaxError: invalid syntax

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
G = nx.graph()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ea0a12f01567> in <module>
# ----> 1 G = nx.graph()
#
# TypeError: 'module' object is not callable

# %%
G = nx.Graph()

# %%
l=[1,2,3]

# %%
G.add_nodes_from(l)

# %%
G=nx.complete_graph(20)

# %%
nx.draw(G)
plt.show()
