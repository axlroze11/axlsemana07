# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_node(1)

# %%
G.add_node(2)

# %%
G.add_node(3)

# %%
G.add_edge(1,2)

# %%
G.add_edge(2,3)

# %%
G.add_edge(1,3)

# %%
print(G.nodes)
# Out:
# [1, 2, 3]

# %%
print(G.edges)
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
nx.draw(G)

# %%
plot.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2821535b2803> in <module>
# ----> 1 plot.show
#
# NameError: name 'plot' is not defined

# %%
nx.draw(G)
plot.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f895474c6c1e> in <module>
#       1 nx.draw(G)
# ----> 2 plot.show
#
# NameError: name 'plot' is not defined

# %%
nx.draw(G)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c831900b3ee2> in <module>
#       1 nx.draw(G)
# ----> 2 plot.show()
#
# NameError: name 'plot' is not defined

# %%
nx.draw(G)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6b657979c632> in <module>
#       1 nx.draw(G)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
nx.draw(G)

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(G)
plt.show()
